# %%
import pandas as pd
import numpy as np
import random

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/data_male_female.csv')
# Out:
# <ipython-input-4-2143b2bb184c>:1: DtypeWarning: Columns (6,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/drive/MyDrive/data_male_female.csv')

# %%
topics = []

for i in range(0, len(df)):
  topics.append(random.randint(1,5))

# %%
df['topics'] = topics

# %%
# Out:
# 0          1
# 1          2
# 2          4
# 3          3
# 4          2
#           ..
# 1184738    5
# 1184739    2
# 1184740    5
# 1184741    1
# 1184742    3
# Name: topics, Length: 1184743, dtype: int64

# %%
chunk = int(np.floor(len(df)/12))

# %%
df1 = df.iloc[1:chunk]
df2 = df.iloc[chunk+1:2*chunk]
df3 = df.iloc[2*chunk+1:3*chunk]
df4 = df.iloc[3*chunk+1:4*chunk]
df5 = df.iloc[4*chunk+1:5*chunk]
df6 = df.iloc[5*chunk+1:6*chunk]
df7 = df.iloc[6*chunk+1:7*chunk]
df8 = df.iloc[7*chunk+1:8*chunk]
df9 = df.iloc[8*chunk+1:9*chunk]
df10 = df.iloc[9*chunk+1:10*chunk]
df11 = df.iloc[10*chunk+1:11*chunk]
df12 = df.iloc[11*chunk+1:len(df)-1]

# %%
df1.to_csv('/content/drive/MyDrive/chunked_data/data_male_female1.csv')
df2.to_csv('/content/drive/MyDrive/chunked_data/data_male_female2.csv')
df3.to_csv('/content/drive/MyDrive/chunked_data/data_male_female3.csv')
df4.to_csv('/content/drive/MyDrive/chunked_data/data_male_female4.csv')
df5.to_csv('/content/drive/MyDrive/chunked_data/data_male_female5.csv')
df6.to_csv('/content/drive/MyDrive/chunked_data/data_male_female6.csv')
df7.to_csv('/content/drive/MyDrive/chunked_data/data_male_female7.csv')
df8.to_csv('/content/drive/MyDrive/chunked_data/data_male_female8.csv')
df9.to_csv('/content/drive/MyDrive/chunked_data/data_male_female9.csv')
df10.to_csv('/content/drive/MyDrive/chunked_data/data_male_female10.csv')
df11.to_csv('/content/drive/MyDrive/chunked_data/data_male_female11.csv')
df12.to_csv('/content/drive/MyDrive/chunked_data/data_male_female12.csv')
